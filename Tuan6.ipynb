# %%
#W6A1
lst = list(map(int,input().split()))
sogiongnhau = []
for i in lst:
    if i not in sogiongnhau:
        sogiongnhau.append(i)
print(sogiongnhau)
# Out:
# [1, 2, 3]

# %%
#W6A2
lst = list(map(int,input().split()))
n = []
tong = 0
for i in lst:
    tong += i
    n.append(tong)
print(n)
# Out:
# [1, 3, 6, 10]

# %%
#W6A3
lst = tuple(map(int,input().split()))
k = int(input())
n = len(lst)
k = k % n
m = lst[k:] + lst[:k]
print(m)
# Out:
# (3, 4, 5, 1, 2)

# %%
#W6A4
lst = list(map(int(input().split())))
s = input().split()

# %%
#W6A5
a = list(map(int,input().split()))
dict = {'positive':0,'negative':0,'zeros':0}
for i in a:
    if i>0 :
        dict['positive']+=1
    elif i<0 :
        dict['negative']+=1
    elif i==0 :
        dict['zeros']+=1
print(dict)
# Out:
# {'positive': 3, 'negative': 1, 'zeros': 2}

# %%
#W6A6
a = list(map(int,input().split()))
tong = 0 
for i in a :
    tong += i
print(tong)
# Out:
# 10

# %%
#W6A7
t = tuple(input().split())
print(t[0])
print(t[-1])
print(t[::-1])
# Out:
# 1
# 6
# ('6', '5', '4', '3', '2', '1')

# %%
#W6A8
dsach = input().split()
kqua = {}
for i in dsach :
    kqua[i] = kqua.get(i,0)+1
print(kqua)
# Out:
# {'a': 3, 'b': 1, 'c': 1}

# %%
#W6A9
dict1 = 
dict2 =
